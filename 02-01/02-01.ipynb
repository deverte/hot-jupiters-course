# %% [markdown]
# # Лекция 2. Задание 1
#
# Вычислить средние значения $\langle n \rangle$ векторов нормали, на тех границах, где это нужно.
#
# $$ d V = d r \times r d \theta \times r \sin \theta d \varphi $$
# $$ d S_{1, 2} = r d \theta \times r \sin \theta d \varphi = r^2 \sin \theta d \theta d \varphi,\ r = \text{const} $$
# $$ d S_{3, 4} = d r \times r \sin \theta d \varphi = r \sin \theta d r d \varphi,\ \theta = \text{const} $$
# $$ d S_{5, 6} = d r \times r d \theta = r d r d \theta,\ \varphi = \text{const} $$
