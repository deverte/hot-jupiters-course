# %% [markdown]
# # Лекция 2. Задание 2
#
# Попробуйте тем же методом вывести схему для сетки в цилиндрических координатах.
#
# $$ d V = d r \times r d \varphi \times d z $$
# $$ d S_{1, 2} = r d \varphi \times d z = r d \varphi d z,\ r = \text{const} $$
# $$ d S_{3, 4} = d r \times d z = d r d z,\ \varphi = \text{const} $$
# $$ d S_{5, 6} = d r \times r d\varphi = r d r d \varphi,\ z = \text{const} $$
