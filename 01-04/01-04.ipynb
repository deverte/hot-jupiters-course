# %% [markdown]
# # Лекция 1. Задание 4
#
# Используя метод неопределенных коэффициентов, найти аппроксимации на неоднородной сетке для одномерных операторов Лапласа в декартовой, цилиндрической и сферической системах координат.
#
# $$ \frac{\partial^2 u}{\partial x^2} $$
#
# $$ \frac{1}{r} \frac{\partial}{\partial r} (r \frac{\partial u}{\partial r}) $$
#
# $$ \frac{1}{r^2} \frac{\partial}{\partial r} (r^2 \frac{\partial u}{\partial r}) $$
